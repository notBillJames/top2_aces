# %%
import mysql.connector as sql
import pandas as pd 
from IPython.display import display
import advanced_statlines as stat

# %%
pd.options.display.max_columns = None

# %%
batting = pd.read_csv('ari2001_batting.csv')

batting.head()
# Out:
#     playerID nameFirst  nameLast     ID playerID.1  yearID  stint teamID  \
# 0  anderbr02     Brian  Anderson  80676  anderbr02    2001      1    ARI
# 1  barajro01       Rod   Barajas  80708  barajro01    2001      1    ARI
# 2  batismi01    Miguel   Batista  80716  batismi01    2001      1    ARI
# 3  bautida01     Danny  Bautista  80720  bautida01    2001      1    ARI
# 4   bellja01       Jay      Bell  80731   bellja01    2001      1    ARI
#
#    team_ID lgID    G  G_batting   AB   R    H  2B  3B  HR  RBI  SB  CS  BB  \
# 0     2357   NL   33        NaN   37   1    5   1   1   0    2   0   0   0
# 1     2357   NL   51        NaN  106   9   17   3   0   3    9   0   0   4
# 2     2357   NL   48        NaN   32   2    2   0   0   0    0   0   0   2
# 3     2357   NL  100        NaN  222  26   67  11   2   5   26   3   2  14
# 4     2357   NL  129        NaN  428  59  106  24   1  13   46   0   1  65
#
#    SO  IBB  HBP  SH  SF  GIDP
# 0   9    0    0   0   0     2
# 1  26    0    0   0   0     0
# 2  17    0    0   2   0     0
# 3  31    1    1   2   0     7
# 4  79    3    4   8   4     9

# %%
stat.format_df(batting)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-89-a15cc2c06903> in <module>
# ----> 1 stat.format_df(batting)
#
# ~/Documents/dev/baseball/top2_aces/advanced_statlines.py in format_df(df)
#       7
#       8 stat_functions = [['pa', PA_lambda], ['obp',OBP_lambda], ['avg', AVG_lambda]]
# ----> 9 def format_df(df):
#      10     for func in stat_functions:
#      11         df[f'func[0]'] = df.apply(func[1], axis=1)
#
# ~/Documents/dev/baseball/top2_aces/top2_aces/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    6876             kwds=kwds,
#    6877         )
# -> 6878         return op.get_result()
#    6879
#    6880     def applymap(self, func) -> "DataFrame":
#
# ~/Documents/dev/baseball/top2_aces/top2_aces/lib/python3.7/site-packages/pandas/core/apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# ~/Documents/dev/baseball/top2_aces/top2_aces/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#     294             try:
#     295                 result = libreduction.compute_reduction(
# --> 296                     values, self.f, axis=self.axis, dummy=dummy, labels=labels
#     297                 )
#     298             except ValueError as err:
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction.compute_reduction()
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction.Reducer.get_result()
#
# ~/Documents/dev/baseball/top2_aces/advanced_statlines.py in <lambda>(row)
#       1 import pandas as pd
#       2
# ----> 3
#       4 PA_lambda = lambda row: row.AB + row.BB + row.HBP + row.SH + row.SF
#       5 OBP_lambda = lambda row: (row.H + row.BB + row.HBP) / (row.PA) if row.PA > 0 else 'NaN'
#
# ~/Documents/dev/baseball/top2_aces/top2_aces/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'PA'

# %%
batting.head()
# Out:
#     playerID nameFirst  nameLast     ID playerID.1  yearID  stint teamID  \
# 0  anderbr02     Brian  Anderson  80676  anderbr02    2001      1    ARI
# 1  barajro01       Rod   Barajas  80708  barajro01    2001      1    ARI
# 2  batismi01    Miguel   Batista  80716  batismi01    2001      1    ARI
# 3  bautida01     Danny  Bautista  80720  bautida01    2001      1    ARI
# 4   bellja01       Jay      Bell  80731   bellja01    2001      1    ARI
#
#    team_ID lgID    G  G_batting   AB   R    H  2B  3B  HR  RBI  SB  CS  BB  \
# 0     2357   NL   33        NaN   37   1    5   1   1   0    2   0   0   0
# 1     2357   NL   51        NaN  106   9   17   3   0   3    9   0   0   4
# 2     2357   NL   48        NaN   32   2    2   0   0   0    0   0   0   2
# 3     2357   NL  100        NaN  222  26   67  11   2   5   26   3   2  14
# 4     2357   NL  129        NaN  428  59  106  24   1  13   46   0   1  65
#
#    SO  IBB  HBP  SH  SF  GIDP  func
# 0   9    0    0   0   0     2    37
# 1  26    0    0   0   0     0   110
# 2  17    0    0   2   0     0    36
# 3  31    1    1   2   0     7   239
# 4  79    3    4   8   4     9   509
