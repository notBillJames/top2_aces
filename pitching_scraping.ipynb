# %%
import pandas as pd 
from bs4 import BeautifulSoup as soup
import requests as req
import numpy
from IPython.display import display
import mysql.connector as sql

pd.options.display.max_columns = None

respone = req.get('https://stathead.com/baseball/season_finder.cgi?request=1&sum=0&order_by_asc=0&order_by=year_id&qualifiersSeason=eratitle&minIpValS=162&minDecValS=14&mingamesValS=40&qualifiersCareer=nomin&minIpValC=1000&minDecValC=100&mingamesValC=200&min_year_season=1947&max_year_season=2019&lg_ID=lgAny&lgAL_team=tmAny&lgNL_team=tmAny&lgFL_team=tmAny&lgAA_team=tmAny&lgPL_team=tmAny&lgUA_team=tmAny&lgNA_team=tmAny&as=result_pitcher&offset=0&type=p&ccomp=gt&cval=&cstat=&cratiostat=&throws=any&min_age=0&max_age=99&min_season=1&max_season=-1&role=anyrole&games_started=60&games_relieved=80&location=pob&locationMatch=is&pob=&pod=&pcanada=&pusa=&is_rookie=&isHOF=either&isAllstar=either&isActive=either')
results1 = soup(respone.content, 'html.parser')
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~/dev/baseball/top2_aces/top2_venv/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     159             conn = connection.create_connection(
# --> 160                 (self._dns_host, self.port), self.timeout, **extra_kw
#     161             )
#
# ~/dev/baseball/top2_aces/top2_venv/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      60
# ---> 61     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      62         af, socktype, proto, canonname, sa = res
#
# /usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     751     addrlist = []
# ...

# %%
table = results1.select('.stats_table')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c3676636a7a6> in <module>
# ----> 1 table = results1.select('.stats_table')
#
# NameError: name 'results1' is not defined
