# %% [markdown]
# # Calculating OPS+
#
# The formula for OPS+ is:
# ```
#     OPS/lgOPS * 100
# ```
# However the problem is making the formula iterable across rows. I'm not sure about how to write a lambda, or function, that makes sure that Player A's OPS is divided by the lgOPS of that year.

# %%
import advanced_statlines as stat 
import pandas as pd 
import numpy as np 
import mysql.connector as sql
from IPython import display

pd.options.display.max_columns = None

# %%
batting = pd.read_csv('multiyear_batting_example.csv')
stat.format_df(batting)
batting = stat.order_by(batting, 'OPS', False)

# %% [markdown]
# What I think will work is by setting the lgOPS inside the function so that it divides by the lgOPS from the proper year. It should look something like this:

# %%
def ops_plus(df):
    lgOPS = df.groupby('yearID').OPS.mean().reset_index()
    for loc in range(len(lgOPS)):
        if df.yearID != lgOPS.yearID.iloc[loc]:
            continue
        row.OPS / lgOPS.OPS.iloc[loc]

batting['OPS+'] = batting.apply(ops_plus(batting), axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-ed4ca8331dc1> in <module>
#       6         row.OPS / lgOPS.OPS.iloc[loc]
#       7
# ----> 8 batting['OPS+'] = batting.apply(ops_plus(batting), axis=1)
#
# <ipython-input-12-ed4ca8331dc1> in ops_plus(df)
#       2     lgOPS = df.groupby('yearID').OPS.mean().reset_index()
#       3     for loc in range(len(lgOPS)):
# ----> 4         if df.yearID != lgOPS.yearID.iloc[loc]:
#       5             continue
#       6         row.OPS / lgOPS.OPS.iloc[loc]
#
# ~/dev/baseball/top2_aces/top2_venv/lib/python3.7/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1477     def __nonzero__(self):
#    1478         raise ValueError(
# -> 1479             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1480             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1481         )
#
# ...
