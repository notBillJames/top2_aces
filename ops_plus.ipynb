# %% [markdown]
# # Calculating OPS+
#
# The formula for OPS+ is:
# ```
#     OPS/lgOPS * 100
# ```
# However the problem is making the formula iterable across rows. I'm not sure about how to write a lambda, or function, that makes sure that Player A's OPS is divided by the lgOPS of that year.

# %%
import advanced_statlines as stat 
import pandas as pd 
import numpy as np 
import mysql.connector as sql
from IPython import display

pd.options.display.max_columns = None

# %%
batting = pd.read_csv('multiyear_batting_example.csv')
stat.format_df(batting)
batting = batting[batting.PA > 350]
batting = stat.order_by(batting, 'OPS', False)
batting.head()
# Out:
#        ID   playerID  yearID  stint teamID  team_ID lgID    G  G_batting   AB  \
# 0  107416  yelicch01    2019      1    MIL     2911   NL  130        NaN  489
# 1  105724  troutmi01    2018      1    LAA     2878   AL  140        NaN  471
# 2  107288  troutmi01    2019      1    LAA     2908   AL  134        NaN  470
# 3  104454  bettsmo01    2018      1    BOS     2869   AL  136        NaN  520
# 4  105912  alvaryo01    2019      1    HOU     2906   AL   87        NaN  313
#
#      R    H  2B  3B  HR  RBI  SB  CS   BB   SO  IBB  HBP  SH  SF  GIDP   PA  \
# 0  100  161  29   3  44   97  30   2   80  118   16    8   0   3     8  580
# 1  101  147  24   4  39   79  24   2  122  124   25   10   0   4     5  607
# 2  110  137  27   2  45  104  11   2  110  120   14   16   0   4     5  600
# 3  129  180  47   5  32   80  30   6   81   91    8    8   0   5     5  614
# 4   58   98  26   0  27   78   0   0   52   94    4    2   0   2     9  369
#
#         OBP       AVG       SLG       OPS
# 0  0.429310  0.329243  0.670757  1.100067
# 1  0.459638  0.312102  0.628450  1.088088
# 2  0.438333  0.291489  0.644681  1.083014
# 3  0.438111  0.346154  0.640385  1.078495
# 4  0.411924  0.313099  0.654952  1.066876

# %%
test_df = batting[(batting.playerID == 'troutmi01') & 
                    (batting.yearID == 2018)]
lgOPS = batting.groupby('yearID').OPS.mean().reset_index()
test_df
# Out:
#        ID   playerID  yearID  stint teamID  team_ID lgID    G  G_batting   AB  \
# 1  105724  troutmi01    2018      1    LAA     2878   AL  140        NaN  471
#
#      R    H  2B  3B  HR  RBI  SB  CS   BB   SO  IBB  HBP  SH  SF  GIDP   PA  \
# 1  101  147  24   4  39   79  24   2  122  124   25   10   0   4     5  607
#
#         OBP       AVG      SLG       OPS
# 1  0.459638  0.312102  0.62845  1.088088

# %%
print(lgOPS)
# Out:
#    yearID       OPS
# 0    2018  0.763437
# 1    2019  0.795498

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-11a041113050> in <module>
# ----> 1 print(lgOPS[lgOPS.yearID == test_df.yearID])
#
# ~/dev/baseball/top2_aces/top2_venv/lib/python3.7/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      62         other = item_from_zerodim(other)
#      63
# ---> 64         return method(self, other)
#      65
#      66     return new_method
#
# ~/dev/baseball/top2_aces/top2_venv/lib/python3.7/site-packages/pandas/core/ops/__init__.py in wrapper(self, other)
#     522
#     523         if isinstance(other, ABCSeries) and not self._indexed_same(other):
# --> 524             raise ValueError("Can only compare identically-labeled Series objects")
#     525
#     526         lvalues = extract_array(self, extract_numpy=True)
#
# ValueError: Can only compare identically-labeled Series objects
