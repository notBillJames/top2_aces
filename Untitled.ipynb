# %%
import advanced_statlines as stat 
import pandas as pd 
import numpy as np 
import mysql.connector as sql
from IPython import display

pd.options.display.max_columns = None

# %%
lahmans = sql.connect(user='root', password='wassup01L', db='lahmansbaseballdb')

pitching_query = '''
        SELECT *
        FROM pitching
        WHERE yearID > 1947 
            AND ERA < 4.00
            AND (IPouts / 3) > 175
'''

pitching_data = pd.read_sql(pitching_query, lahmans)
by_IP = order_by(pitching_data, IPouts, False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-3195bc5d0f0a> in <module>
#      10
#      11 pitching_data = pd.read_sql(pitching_query, lahmans)
# ---> 12 by_IP = order_by(pitching_data, IPouts, False)
#
# NameError: name 'order_by' is not defined

# %%
pitching_data.head()
# Out:
#       ID   playerID  yearID  stint teamID  team_ID lgID   W   L   G  GS  CG  \
# 0  12868  barnere02    1948      1    BRO     1153   NL  15  13  44  34  12
# 1  12870  beardge01    1948      1    CLE     1158   AL  20   7  37  29  15
# 2  12885  brancra01    1948      1    BRO     1153   NL  14   9  36  28  11
# 3  12887  brechha01    1948      1    SLN     1166   NL  20   7  33  30  21
# 4  12898  chesnbo01    1948      1    PIT     1164   NL  14   6  25  23  15
#
#    SHO  SV  IPouts    H  ER  HR   BB   SO  BAOpp   ERA  IBB  WP  HBP  BK  \
# 0    4   0     740  193  85  17  122  138   0.21  3.10  NaN   4    6   1
# 1    6   1     689  187  62   9  106   80   0.22  2.43  NaN   5    3   0
# 2    1   1     647  189  84  24   80  122   0.23  3.51  NaN   9    4   0
# 3    7   1     700  193  58   6   49  149   0.22  2.24  NaN   2    2   1
# 4    0   0     583  180  77  13   90   69   0.24  3.57  NaN   6    4   2
#
#     BFP  GF    R  SH  SF  GIDP
# 0  1028   6  101 NaN NaN   NaN
# 1   935   4   72 NaN NaN   NaN
# 2   905   4   93 NaN NaN   NaN
# 3   931   1   62 NaN NaN   NaN
# 4   829   0   92 NaN NaN   NaN
