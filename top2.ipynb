# %%
import mysql.connector as sql
import pandas as pd 
import numpy as np 
import advanced_statlines as stat

# %%
lahmans = sql.connect(user='root', passwd='wassup01L', db='lahmansbaseballdb')
# Out:
# ---------------------------------------------------------------------------
# NotSupportedError                         Traceback (most recent call last)
# <ipython-input-5-9f2d904f99f7> in <module>
# ----> 1 lahmans = sql.connect(user='root', passwd='wassup01L', db='lahmansbaseballdb')
#
# ~/Documents/dev/baseball/top2_aces/top2_venv/lib/python3.7/site-packages/mysql/connector/__init__.py in connect(*args, **kwargs)
#     177         return CMySQLConnection(*args, **kwargs)
#     178     else:
# --> 179         return MySQLConnection(*args, **kwargs)
#     180 Connect = connect  # pylint: disable=C0103
#     181
#
# ~/Documents/dev/baseball/top2_aces/top2_venv/lib/python3.7/site-packages/mysql/connector/connection.py in __init__(self, *args, **kwargs)
#      93
#      94         if len(kwargs) > 0:
# ---> 95             self.connect(**kwargs)
#      96
#      97     def _do_handshake(self):
#
# ...

# %%
pd.options.display.max_columns = None

# %%
batting = pd.read_csv('ari2001_batting.csv')
batting.head()
# Out:
#     playerID nameFirst  nameLast     ID playerID.1  yearID  stint teamID  \
# 0  anderbr02     Brian  Anderson  80676  anderbr02    2001      1    ARI
# 1  barajro01       Rod   Barajas  80708  barajro01    2001      1    ARI
# 2  batismi01    Miguel   Batista  80716  batismi01    2001      1    ARI
# 3  bautida01     Danny  Bautista  80720  bautida01    2001      1    ARI
# 4   bellja01       Jay      Bell  80731   bellja01    2001      1    ARI
#
#    team_ID lgID    G  G_batting   AB   R    H  2B  3B  HR  RBI  SB  CS  BB  \
# 0     2357   NL   33        NaN   37   1    5   1   1   0    2   0   0   0
# 1     2357   NL   51        NaN  106   9   17   3   0   3    9   0   0   4
# 2     2357   NL   48        NaN   32   2    2   0   0   0    0   0   0   2
# 3     2357   NL  100        NaN  222  26   67  11   2   5   26   3   2  14
# 4     2357   NL  129        NaN  428  59  106  24   1  13   46   0   1  65
#
#    SO  IBB  HBP  SH  SF  GIDP
# 0   9    0    0   0   0     2
# ...

# %%
batting_formatted = stat.format_df(batting)
display(batting_formatted)
# Out:
#      playerID   nameFirst     nameLast     ID playerID.1  yearID  stint  \
# 0   anderbr02       Brian     Anderson  80676  anderbr02    2001      1
# 1   barajro01         Rod      Barajas  80708  barajro01    2001      1
# 2   batismi01      Miguel      Batista  80716  batismi01    2001      1
# 3   bautida01       Danny     Bautista  80720  bautida01    2001      1
# 4    bellja01         Jay         Bell  80731   bellja01    2001      1
# 5   bierbni01        Nick    Bierbrodt  80754  bierbni01    2001      1
# 6   brohatr01        Troy      Brohawn  80794  brohatr01    2001      1
# 7   chrisry01        Ryan  Christenson  80864  chrisry01    2001      2
# 8   cintral01        Alex      Cintron  80866  cintral01    2001      1
# 9   colbrgr01        Greg     Colbrunn  80879  colbrgr01    2001      1
# 10  contija01       Jason        Conti  80886  contija01    2001      1
# 11  counscr01       Craig     Counsell  80901  counscr01    2001      1
# ...
